# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[1234,4321,3854,0,1]])
# Out:
# C:\Users\agnim\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43934.57902014]])
